# %% [markdown]
# ## Technical Exercise for Data Scientist Candidates
#
# ##### Author: Wenli Zhang
# ##### Date: Aug 2021

# %% [markdown]
# ## Content

# %% [markdown]
# 1. [Import libraries](#libraries)
# 1. [Question List](#Question_List)

# %% [markdown]
# ## 1. Import libraries
#
# <a id='libraries'></a>

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime
from scipy.sparse import csr_matrix

import nltk
from nltk.corpus import stopwords

from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
from textblob import TextBlob
from sklearn.cluster import SpectralClustering
from sklearn.decomposition import PCA


# Reports
import plotly
import chart_studio
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
import plotly.express as px
#import plotly.figure_factory as ff
import plotly.io as pio
pio.renderers.default = "svg" # for plotly report to show as image in github

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\wzhang\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 2. Question List
#
# <a id='Question_List'></a>

# %% [markdown]
# 1. [Rank top 3 Breweries which produce the strongest beers?](#Q1)
# 1. [Which year did beers enjoy the highest ratings?](#Q2)
# 1. [Based on the user’s ratings which factors are important among taste, aroma, appearance, and palette?](#Q3)
# 1. [If you were to recommend 3 beers to your friends based on this data which ones will you recommend?](#Q4)
# 1. [Which Beer style seems to be the favorite based on reviews written by users?](#Q5)
# 1. [How does written review compare to overall review score for the beer styles?](#Q6)
# 1. [How do find similar beer drinkers by using written reviews only? ](#Q7)

# %%
dfbeer=pd.read_csv('BeerDataScienceProject.csv',encoding = "ISO-8859-1")
dfbeer.head()
# Out:
#    beer_ABV  beer_beerId  beer_brewerId               beer_name  \
# 0       5.0        47986          10325            Sausa Weizen
# 1       6.2        48213          10325                Red Moon
# 2       6.5        48215          10325  Black Horse Black Beer
# 3       5.0        47969          10325              Sausa Pils
# 4       7.7        64883           1075           Cauldron DIPA
#
#                        beer_style  review_appearance  review_palette  \
# 0                      Hefeweizen                2.5             2.0
# 1              English Strong Ale                3.0             2.5
# 2          Foreign / Export Stout                3.0             2.5
# 3                 German Pilsener                3.5             3.0
# 4  American Double / Imperial IPA                4.0             4.5
#
#    review_overall  review_taste review_profileName  review_aroma  \
# 0             1.5           1.5            stcules           1.5
# 1             3.0           3.0            stcules           3.0
# 2             3.0           3.0            stcules           3.0
# 3             3.0           2.5            stcules           3.0
# 4             4.0           4.0     johnmichaelsen           4.5
#
#                                          review_text  review_time
# 0  A lot of foam. But a lot. In the smell some ba...   1234817823
# 1  Dark red color, light beige foam, average. In ...   1235915097
# 2  Almost totally black. Beige foam, quite compac...   1235916604
# 3  Golden yellow color. White, compact foam, quit...   1234725145
# 4  According to the website, the style for the Ca...   1293735206

# %%
dfbeer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528870 entries, 0 to 528869
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   beer_ABV            508590 non-null  float64
#  1   beer_beerId         528870 non-null  int64
#  2   beer_brewerId       528870 non-null  int64
#  3   beer_name           528870 non-null  object
#  4   beer_style          528870 non-null  object
#  5   review_appearance   528870 non-null  float64
#  6   review_palette      528870 non-null  float64
#  7   review_overall      528870 non-null  float64
#  8   review_taste        528870 non-null  float64
#  9   review_profileName  528755 non-null  object
#  10  review_aroma        528870 non-null  float64
#  11  review_text         528751 non-null  object
#  12  review_time         528870 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 52.5+ MB

# %%
dfbeer.describe(include='all')
# Out:
#              beer_ABV    beer_beerId  beer_brewerId  \
# count   508590.000000  528870.000000  528870.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean         7.017442   22098.466016    2598.423429
# std          2.204460   22158.284352    5281.805350
# min          0.010000       3.000000       1.000000
# 25%          5.300000    1745.000000     132.000000
# 50%          6.500000   14368.000000     394.000000
# 75%          8.500000   40528.000000    1475.000000
# max         57.700000   77310.000000   27980.000000
#
#                             beer_name    beer_style  review_appearance  \
# count                          528870        528870      528870.000000
# unique                          18339           104                NaN
# top     Sierra Nevada Celebration Ale  American IPA                NaN
# freq                             3000         43369                NaN
# mean                              NaN           NaN           3.864522
# std                               NaN           NaN           0.604010
# min                               NaN           NaN           0.000000
# 25%                               NaN           NaN           3.500000
# 50%                               NaN           NaN           4.000000
# 75%                               NaN           NaN           4.000000
# max                               NaN           NaN           5.000000
#
#         review_palette  review_overall   review_taste review_profileName  \
# count    528870.000000   528870.000000  528870.000000             528755
# unique             NaN             NaN            NaN              22800
# top                NaN             NaN            NaN     northyorksammy
# freq               NaN             NaN            NaN               1858
# mean          3.758926        3.833197       3.765993                NaN
# std           0.685335        0.709962       0.669018                NaN
# min           1.000000        0.000000       1.000000                NaN
# 25%           3.500000        3.500000       3.500000                NaN
# 50%           4.000000        4.000000       4.000000                NaN
# 75%           4.000000        4.500000       4.000000                NaN
# max           5.000000        5.000000       5.000000                NaN
#
#          review_aroma review_text   review_time
# count   528870.000000      528751  5.288700e+05
# unique            NaN      528371           NaN
# top               NaN      #NAME?           NaN
# freq              NaN          92           NaN
# mean         3.817350         NaN  1.224885e+09
# std          0.718903         NaN  7.605600e+07
# min          1.000000         NaN  8.843904e+08
# 25%          3.500000         NaN  1.174613e+09
# 50%          4.000000         NaN  1.240366e+09
# 75%          4.500000         NaN  1.288560e+09
# max          5.000000         NaN  1.326277e+09

# %%
# Key information after data inspection:
# total record count:528870
# beer_style: 104 
# user: 22800

# %%
# get year from utcfromtimestamp
dfbeer['review_year'] = dfbeer.apply(lambda row: datetime.utcfromtimestamp(row.review_time).strftime("%Y"), axis=1)
dfbeer.head()
# Out:
#    beer_ABV  beer_beerId  beer_brewerId               beer_name  \
# 0       5.0        47986          10325            Sausa Weizen
# 1       6.2        48213          10325                Red Moon
# 2       6.5        48215          10325  Black Horse Black Beer
# 3       5.0        47969          10325              Sausa Pils
# 4       7.7        64883           1075           Cauldron DIPA
#
#                        beer_style  review_appearance  review_palette  \
# 0                      Hefeweizen                2.5             2.0
# 1              English Strong Ale                3.0             2.5
# 2          Foreign / Export Stout                3.0             2.5
# 3                 German Pilsener                3.5             3.0
# 4  American Double / Imperial IPA                4.0             4.5
#
#    review_overall  review_taste review_profileName  review_aroma  \
# 0             1.5           1.5            stcules           1.5
# 1             3.0           3.0            stcules           3.0
# 2             3.0           3.0            stcules           3.0
# 3             3.0           2.5            stcules           3.0
# 4             4.0           4.0     johnmichaelsen           4.5
#
#                                          review_text  review_time review_year
# 0  A lot of foam. But a lot. In the smell some ba...   1234817823        2009
# 1  Dark red color, light beige foam, average. In ...   1235915097        2009
# 2  Almost totally black. Beige foam, quite compac...   1235916604        2009
# 3  Golden yellow color. White, compact foam, quit...   1234725145        2009
# 4  According to the website, the style for the Ca...   1293735206        2010

# %%
#check null value
dfbeer.isnull().sum()
# Out:
# beer_ABV              20280
# beer_beerId               0
# beer_brewerId             0
# beer_name                 0
# beer_style                0
# review_appearance         0
# review_palette            0
# review_overall            0
# review_taste              0
# review_profileName      115
# review_aroma              0
# review_text             119
# review_time               0
# review_year               0
# dtype: int64

# %%
# Since null counts for review_profileName and review_text are in small percentage, and both are needed for questions asked, so simply drop rows involved
dfbeer = dfbeer[dfbeer['review_profileName'].notna() & dfbeer['review_text'].notna()]
dfbeer.shape
# Out:
# (528636, 14)

# %%
# There are multiple entries by same user for same beer name, keep only the most recent entry
dfbeer_dup=dfbeer[dfbeer.groupby(['beer_style','beer_name'])['review_time'].transform('count') > 1]
dfbeer_dup.shape
# Out:
# (522273, 14)

# %%
# Sort data by review_time descending; keep the first in each unique'review_profileName' + 'beer_name'
dfbeer = dfbeer.sort_values('review_time', ascending=False)
dfbeer = dfbeer.drop_duplicates(subset= ['review_profileName','beer_name'], keep='first')
dfbeer.shape
# Out:
# (522701, 14)

# %% [markdown]
# ### 1. Rank top 3 Breweries which produce the strongest beers?
# <a id='Q1'></a>

# %% [markdown]
# ### 2. Which year did beers enjoy the highest ratings?
# <a id='Q2'></a>

# %% [markdown]
# ### 3. Based on the user’s ratings which factors are important among taste, aroma, appearance, and palette?
# <a id='Q3'></a>

# %% [markdown]
# ### 4. Which year did beers enjoy the highest ratings?
# <a id='Q4'></a>

# %% [markdown]
# ### 5. Which Beer style seems to be the favorite based on reviews written by users?
# <a id='Q5'></a>

# %% [markdown]
# ### 6. How does written review compare to overall review score for the beer styles?
# <a id='Q6'></a>

# %% [markdown]
# ### 7. How to find similar beer drinkers by using written reviews only?
# <a id='Q7'></a>

# %%
def clean_text(text):
   # text pre-processing

    text = text.lower()
    
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"\'t", " not", text)
    
    #Spelling correction
    text = TextBlob(text).correct()
    
    # Only keep letters
    #skip this step since it doesn't make difference to the sentimental analysis method used
    
    # Lemmatization
    # can be time consuming
    #skip this step since it doesn't make difference to the sentimental analysis method used
      
    # Remove stop words
    # can be time consuming
    #skip this step since it doesn't make difference to the sentimental analysis method used
    return text

# %%
#dfbeer['review_text_clean']=dfbeer['review_text'].apply(lambda text:clean_text(text))
dfbeer['review_text_clean']=dfbeer['review_text']

# %%
# Using TextBlob to calculate sentiment polarity in the range of [-1,1]
# 1 = positive sentiment and -1 =negative sentiment
dfbeer['review_text_senti'] = dfbeer['review_text_clean'].apply(lambda text: TextBlob(text).sentiment.polarity)
intensityanalyzer = SentimentIntensityAnalyzer()
#dfbeer['review_text_senti'] = dfbeer['review_text_clean'].apply(lambda text: intensityanalyzer.polarity_scores(text)['compound'])

# %%
# If a user rated more than one beer names within one beer_style, use the mean value
senti_matrix = dfbeer.groupby(['review_profileName','beer_style'])['review_text_senti'].mean().unstack()

# %%
senti_matrix.head()
# Out:
# beer_style          Altbier  American Adjunct Lager  American Amber / Red Ale  \
# review_profileName
# 0110x011                NaN                     NaN                  0.147527
# 03SVTCobra              NaN                     NaN                       NaN
# 04101Brewer             NaN                     NaN                       NaN
# 05Harley                NaN                     NaN                  0.196402
# 0runkp0s                NaN               -0.023611                       NaN
#
# beer_style          American Amber / Red Lager  American Barleywine  \
# review_profileName
# 0110x011                                   NaN             0.169634
# 03SVTCobra                                 NaN                  NaN
# 04101Brewer                                NaN                  NaN
# 05Harley                                   NaN             0.047833
# 0runkp0s                                   NaN                  NaN
#
# beer_style          American Black Ale  American Blonde Ale  \
# review_profileName
# 0110x011                           NaN                  NaN
# 03SVTCobra                         NaN                  NaN
# 04101Brewer                        NaN                  NaN
# 05Harley                       0.20899                  NaN
# 0runkp0s                           NaN                  NaN
#
# beer_style          American Brown Ale  American Dark Wheat Ale  \
# review_profileName
# 0110x011                           NaN                      NaN
# 03SVTCobra                         NaN                      NaN
# 04101Brewer                        NaN                      NaN
# 05Harley                           NaN                      NaN
# 0runkp0s                           NaN                      NaN
#
# beer_style          American Double / Imperial IPA  ...  \
# review_profileName                                  ...
# 0110x011                                  0.091440  ...
# 03SVTCobra                                     NaN  ...
# 04101Brewer                                    NaN  ...
# 05Harley                                  0.171955  ...
# 0runkp0s                                       NaN  ...
#
# beer_style          Scotch Ale / Wee Heavy  Scottish Ale  \
# review_profileName
# 0110x011                               NaN           NaN
# 03SVTCobra                             NaN           NaN
# 04101Brewer                            NaN           NaN
# 05Harley                               NaN           NaN
# 0runkp0s                               NaN           NaN
#
# beer_style          Scottish Gruit / Ancient Herbed Ale  Smoked Beer  \
# review_profileName
# 0110x011                                            NaN          NaN
# 03SVTCobra                                          NaN          NaN
# 04101Brewer                                         NaN          NaN
# 05Harley                                            NaN     0.259492
# 0runkp0s                                            NaN          NaN
#
# beer_style            Tripel  Vienna Lager  Weizenbock  Wheatwine  \
# review_profileName
# 0110x011            0.162071           NaN         NaN        NaN
# 03SVTCobra               NaN           NaN         NaN        NaN
# 04101Brewer              NaN           NaN         NaN        NaN
# 05Harley            0.232556      0.285185    0.111205   0.006852
# 0runkp0s                 NaN           NaN         NaN        NaN
#
# beer_style          Winter Warmer   Witbier
# review_profileName
# 0110x011                      NaN  0.264074
# 03SVTCobra                    NaN       NaN
# 04101Brewer                   NaN       NaN
# 05Harley                      NaN       NaN
# 0runkp0s                      NaN       NaN
#
# [5 rows x 104 columns]

# %%
# There are 55 beer drinkers having sentiment.polarity=0 based on their review_text. Since this is 0.2% of total beer drinkers, 0 is not handled before making senti_matrix a sparse.csr_matrix 
senti_matrix[(senti_matrix==0).sum(axis=1)>0]
# Out:
# beer_style           Altbier  American Adjunct Lager  \
# review_profileName
# AlexF                    NaN                     NaN
# Bajasith                 NaN                     NaN
# BaronBeerGoggles         NaN                     NaN
# Beer4Baltimore           NaN                     NaN
# BenH1068                 NaN                     NaN
# BigJTrucker              NaN                0.009214
# BoozySmurf               NaN                0.000000
# Cavalier92          0.378571                     NaN
# DaleMcMutt               NaN                     NaN
# Dhren1979                NaN                     NaN
# Docer               0.351608                0.161111
# Dodt                     NaN                0.227780
# HighGravityBrews         NaN                0.000000
# Imbiber                  NaN                0.054106
# JudgeRoughneck      0.089319                0.106853
# RoryDoherty              NaN                     NaN
# RustyDiamond             NaN                0.000000
# Shadow1100               NaN                0.128577
# TaddyPorter              NaN                     NaN
# TheDeuce                 NaN                0.156347
# TinPigeon                NaN                     NaN
# Tundruth            0.083631                0.066893
# VonSands                 NaN                     NaN
# Vvall                    NaN                0.244535
# alcurtsinger             NaN                     NaN
# bierguru                 NaN                     NaN
# boatyard                 NaN                0.194750
# bonk0076                 NaN                     NaN
# canadianbarman           NaN                0.027083
# cassanoj                 NaN                     NaN
# cswhitehorse        0.113938               -0.016667
# dedrinker           0.407692                0.084325
# diablo14                 NaN                0.132535
# dwvarner77               NaN                     NaN
# fainster                 NaN                0.000000
# foofightingfrog     0.291667                     NaN
# geckointhebox            NaN                     NaN
# hixsonj                  NaN                     NaN
# hopdog              0.083333                0.025872
# inebrius                 NaN                0.098958
# jeffress                 NaN                     NaN
# jjohnson                 NaN                     NaN
# juhl31                   NaN                     NaN
# jwhite1979          0.184809                0.000000
# keethrax                 NaN                0.122851
# leedorham                NaN               -0.015575
# mickcov1                 NaN                     NaN
# mjsheehan08              NaN                     NaN
# ndolover                 NaN                     NaN
# pbrian              0.028906                0.001563
# rlambert                 NaN                     NaN
# rodenbach99         0.000000                0.037500
# sohio                    NaN                     NaN
# stephendr          -0.052015                0.118303
# stingrayvr6         0.146667                     NaN
#
# beer_style          American Amber / Red Ale  American Amber / Red Lager  \
# review_profileName
# AlexF                                    NaN                         NaN
# Bajasith                            0.216139                         NaN
# BaronBeerGoggles                         NaN                         NaN
# Beer4Baltimore                      0.071905                         NaN
# BenH1068                                 NaN                         NaN
# BigJTrucker                         0.286280                         NaN
# BoozySmurf                               NaN                         NaN
# Cavalier92                          0.000000                   -0.030952
# DaleMcMutt                               NaN                         NaN
# Dhren1979                                NaN                         NaN
# Docer                               0.207078                         NaN
# Dodt                                0.477778                         NaN
# HighGravityBrews                         NaN                         NaN
# Imbiber                             0.057813                         NaN
# JudgeRoughneck                      0.146950                         NaN
# RoryDoherty                              NaN                         NaN
# RustyDiamond                        0.191895                         NaN
# Shadow1100                               NaN                         NaN
# TaddyPorter                              NaN                         NaN
# TheDeuce                            0.192691                    0.289950
# TinPigeon                                NaN                         NaN
# Tundruth                                 NaN                         NaN
# VonSands                                 NaN                         NaN
# Vvall                                    NaN                         NaN
# alcurtsinger                             NaN                         NaN
# bierguru                            0.101456                         NaN
# boatyard                                 NaN                         NaN
# bonk0076                           -0.021429                         NaN
# canadianbarman                      0.066667                    0.000000
# cassanoj                            0.410476                         NaN
# cswhitehorse                        0.198274                         NaN
# dedrinker                           0.153343                         NaN
# diablo14                            0.345871                         NaN
# dwvarner77                          0.176096                         NaN
# fainster                            0.221008                         NaN
# foofightingfrog                          NaN                         NaN
# geckointhebox                            NaN                         NaN
# hixsonj                                  NaN                         NaN
# hopdog                              0.053334                    0.132870
# inebrius                            0.123472                         NaN
# jeffress                                 NaN                         NaN
# jjohnson                                 NaN                         NaN
# juhl31                              0.037340                         NaN
# jwhite1979                               NaN                         NaN
# keethrax                                 NaN                    0.032262
# leedorham                           0.364795                         NaN
# mickcov1                                 NaN                         NaN
# mjsheehan08                         0.283619                         NaN
# ndolover                                 NaN                         NaN
# pbrian                              0.152626                         NaN
# rlambert                                 NaN                         NaN
# rodenbach99                        -0.040937                    0.193333
# sohio                                    NaN                         NaN
# stephendr                           0.034614                    0.102667
# stingrayvr6                         0.228355                         NaN
#
# beer_style          American Barleywine  American Black Ale  \
# review_profileName
# AlexF                          0.235198                 NaN
# Bajasith                            NaN                 NaN
# BaronBeerGoggles                    NaN                 NaN
# Beer4Baltimore                 0.000000            0.112885
# BenH1068                            NaN                 NaN
# BigJTrucker                    0.205299                 NaN
# BoozySmurf                          NaN                 NaN
# Cavalier92                          NaN                 NaN
# DaleMcMutt                          NaN                 NaN
# Dhren1979                      0.361632                 NaN
# Docer                          0.196679            0.074695
# Dodt                           0.359630            0.076190
# HighGravityBrews                    NaN                 NaN
# Imbiber                        0.202381                 NaN
# JudgeRoughneck                 0.231016                 NaN
# RoryDoherty                         NaN                 NaN
# RustyDiamond                   0.199891            0.075463
# Shadow1100                          NaN                 NaN
# TaddyPorter                         NaN                 NaN
# TheDeuce                      -0.052083                 NaN
# TinPigeon                           NaN                 NaN
# Tundruth                            NaN                 NaN
# VonSands                            NaN                 NaN
# Vvall                               NaN                 NaN
# alcurtsinger                        NaN                 NaN
# bierguru                       0.000000            0.202167
# boatyard                            NaN                 NaN
# bonk0076                      -0.133333            0.078333
# canadianbarman                      NaN                 NaN
# cassanoj                            NaN                 NaN
# cswhitehorse                   0.134940                 NaN
# dedrinker                      0.171111            0.143182
# diablo14                       0.179968                 NaN
# dwvarner77                          NaN                 NaN
# fainster                            NaN                 NaN
# foofightingfrog                     NaN                 NaN
# geckointhebox                       NaN                 NaN
# hixsonj                             NaN                 NaN
# hopdog                         0.034172           -0.041667
# inebrius                       0.153836                 NaN
# jeffress                            NaN                 NaN
# jjohnson                            NaN                 NaN
# juhl31                         0.159707            0.000000
# jwhite1979                          NaN                 NaN
# keethrax                            NaN                 NaN
# leedorham                      0.168333                 NaN
# mickcov1                            NaN                 NaN
# mjsheehan08                         NaN            0.251806
# ndolover                            NaN                 NaN
# pbrian                              NaN                 NaN
# rlambert                            NaN                 NaN
# rodenbach99                    0.000000                 NaN
# sohio                               NaN                 NaN
# stephendr                      0.051643                 NaN
# stingrayvr6                         NaN                 NaN
#
# beer_style          American Blonde Ale  American Brown Ale  \
# review_profileName
# AlexF                          0.280856            0.117330
# Bajasith                       0.167467            0.000000
# BaronBeerGoggles                    NaN                 NaN
# Beer4Baltimore                 0.084259                 NaN
# BenH1068                            NaN                 NaN
# BigJTrucker                         NaN            0.166667
# BoozySmurf                          NaN                 NaN
# Cavalier92                          NaN                 NaN
# DaleMcMutt                          NaN                 NaN
# Dhren1979                           NaN                 NaN
# Docer                          0.268513            0.301857
# Dodt                                NaN            0.366667
# HighGravityBrews                    NaN                 NaN
# Imbiber                             NaN                 NaN
# JudgeRoughneck                 0.087419            0.071732
# RoryDoherty                         NaN                 NaN
# RustyDiamond                        NaN                 NaN
# Shadow1100                          NaN                 NaN
# TaddyPorter                         NaN                 NaN
# TheDeuce                       0.195342            0.148093
# TinPigeon                           NaN                 NaN
# Tundruth                            NaN                 NaN
# VonSands                            NaN                 NaN
# Vvall                               NaN                 NaN
# alcurtsinger                        NaN                 NaN
# bierguru                            NaN            0.170409
# boatyard                            NaN                 NaN
# bonk0076                            NaN                 NaN
# canadianbarman                      NaN                 NaN
# cassanoj                            NaN            0.024286
# cswhitehorse                   0.270598            0.016370
# dedrinker                      0.146085           -0.045660
# diablo14                       0.213549                 NaN
# dwvarner77                          NaN                 NaN
# fainster                       0.339167                 NaN
# foofightingfrog                     NaN                 NaN
# geckointhebox                       NaN                 NaN
# hixsonj                             NaN                 NaN
# hopdog                         0.097266           -0.091667
# inebrius                       0.063687            0.319048
# jeffress                            NaN                 NaN
# jjohnson                            NaN                 NaN
# juhl31                         0.194872            0.122593
# jwhite1979                          NaN                 NaN
# keethrax                       0.000000            0.117708
# leedorham                           NaN                 NaN
# mickcov1                            NaN                 NaN
# mjsheehan08                         NaN           -0.072222
# ndolover                            NaN                 NaN
# pbrian                         0.009537            0.132955
# rlambert                            NaN                 NaN
# rodenbach99                    0.126779           -0.014444
# sohio                               NaN                 NaN
# stephendr                     -0.028333           -0.070833
# stingrayvr6                         NaN                 NaN
#
# beer_style          American Dark Wheat Ale  American Double / Imperial IPA  \
# review_profileName
# AlexF                                   NaN                             NaN
# Bajasith                                NaN                        0.100000
# BaronBeerGoggles                        NaN                             NaN
# Beer4Baltimore                          NaN                        0.057658
# BenH1068                                NaN                             NaN
# BigJTrucker                             NaN                        0.228478
# BoozySmurf                              NaN                             NaN
# Cavalier92                              NaN                             NaN
# DaleMcMutt                              NaN                             NaN
# Dhren1979                               NaN                        0.177772
# Docer                                   NaN                        0.171869
# Dodt                                    NaN                        0.072738
# HighGravityBrews                        NaN                             NaN
# Imbiber                                 NaN                             NaN
# JudgeRoughneck                          NaN                        0.157778
# RoryDoherty                             NaN                             NaN
# RustyDiamond                            NaN                        0.172516
# Shadow1100                              NaN                             NaN
# TaddyPorter                             NaN                        0.187536
# TheDeuce                           0.346296                        0.134987
# TinPigeon                               NaN                             NaN
# Tundruth                                NaN                             NaN
# VonSands                                NaN                             NaN
# Vvall                                   NaN                             NaN
# alcurtsinger                            NaN                             NaN
# bierguru                                NaN                        0.176817
# boatyard                                NaN                             NaN
# bonk0076                                NaN                             NaN
# canadianbarman                          NaN                             NaN
# cassanoj                                NaN                        0.125781
# cswhitehorse                            NaN                        0.187152
# dedrinker                               NaN                        0.130999
# diablo14                                NaN                             NaN
# dwvarner77                              NaN                        0.052222
# fainster                                NaN                             NaN
# foofightingfrog                         NaN                             NaN
# geckointhebox                           NaN                             NaN
# hixsonj                                 NaN                             NaN
# hopdog                                  NaN                        0.105032
# inebrius                                NaN                        0.257143
# jeffress                                NaN                             NaN
# jjohnson                                NaN                             NaN
# juhl31                                  NaN                        0.161189
# jwhite1979                              NaN                             NaN
# keethrax                                NaN                             NaN
# leedorham                               NaN                        0.150169
# mickcov1                                NaN                             NaN
# mjsheehan08                             NaN                        0.233748
# ndolover                                NaN                             NaN
# pbrian                                  NaN                        0.291667
# rlambert                                NaN                             NaN
# rodenbach99                             NaN                        0.000000
# sohio                                   NaN                             NaN
# stephendr                          0.080000                        0.042521
# stingrayvr6                             NaN                        0.196764
#
# beer_style          ...  Scotch Ale / Wee Heavy  Scottish Ale  \
# review_profileName  ...
# AlexF               ...                0.175919           NaN
# Bajasith            ...                     NaN      0.000183
# BaronBeerGoggles    ...                     NaN           NaN
# Beer4Baltimore      ...                0.219583           NaN
# BenH1068            ...                     NaN           NaN
# BigJTrucker         ...                0.102500           NaN
# BoozySmurf          ...                     NaN           NaN
# Cavalier92          ...                     NaN           NaN
# DaleMcMutt          ...                     NaN           NaN
# Dhren1979           ...                0.471705           NaN
# Docer               ...                0.203486           NaN
# Dodt                ...                     NaN           NaN
# HighGravityBrews    ...                     NaN           NaN
# Imbiber             ...                     NaN      0.152585
# JudgeRoughneck      ...                     NaN           NaN
# RoryDoherty         ...                     NaN           NaN
# RustyDiamond        ...                     NaN           NaN
# Shadow1100          ...                     NaN           NaN
# TaddyPorter         ...                0.204404           NaN
# TheDeuce            ...               -0.083507           NaN
# TinPigeon           ...                     NaN           NaN
# Tundruth            ...                     NaN           NaN
# VonSands            ...                     NaN           NaN
# Vvall               ...                0.425000           NaN
# alcurtsinger        ...                     NaN           NaN
# bierguru            ...                     NaN           NaN
# boatyard            ...                     NaN           NaN
# bonk0076            ...                0.283333           NaN
# canadianbarman      ...                     NaN           NaN
# cassanoj            ...                0.162917           NaN
# cswhitehorse        ...                0.136667      0.000000
# dedrinker           ...                0.008272     -0.063889
# diablo14            ...                     NaN      0.231062
# dwvarner77          ...                     NaN           NaN
# fainster            ...                     NaN           NaN
# foofightingfrog     ...                     NaN           NaN
# geckointhebox       ...                     NaN           NaN
# hixsonj             ...                     NaN           NaN
# hopdog              ...                0.097848      0.206715
# inebrius            ...                     NaN      0.343750
# jeffress            ...                     NaN           NaN
# jjohnson            ...                     NaN           NaN
# juhl31              ...                     NaN           NaN
# jwhite1979          ...                     NaN           NaN
# keethrax            ...                     NaN           NaN
# leedorham           ...                     NaN           NaN
# mickcov1            ...                     NaN           NaN
# mjsheehan08         ...                     NaN           NaN
# ndolover            ...                     NaN           NaN
# pbrian              ...               -0.079167      0.178175
# rlambert            ...                     NaN           NaN
# rodenbach99         ...                0.077407      0.195000
# sohio               ...                     NaN           NaN
# stephendr           ...                     NaN           NaN
# stingrayvr6         ...                0.269921      0.241667
#
# beer_style          Scottish Gruit / Ancient Herbed Ale  Smoked Beer  \
# review_profileName
# AlexF                                               NaN          NaN
# Bajasith                                            NaN          NaN
# BaronBeerGoggles                                    NaN          NaN
# Beer4Baltimore                                      NaN          NaN
# BenH1068                                            NaN          NaN
# BigJTrucker                                         NaN     0.279861
# BoozySmurf                                          NaN          NaN
# Cavalier92                                          NaN          NaN
# DaleMcMutt                                          NaN          NaN
# Dhren1979                                           NaN          NaN
# Docer                                               NaN          NaN
# Dodt                                                NaN          NaN
# HighGravityBrews                                    NaN          NaN
# Imbiber                                             NaN          NaN
# JudgeRoughneck                                      NaN          NaN
# RoryDoherty                                         NaN          NaN
# RustyDiamond                                        NaN          NaN
# Shadow1100                                          NaN          NaN
# TaddyPorter                                         NaN          NaN
# TheDeuce                                            NaN          NaN
# TinPigeon                                           NaN          NaN
# Tundruth                                            NaN          NaN
# VonSands                                            NaN          NaN
# Vvall                                               NaN          NaN
# alcurtsinger                                        NaN          NaN
# bierguru                                            NaN          NaN
# boatyard                                            NaN          NaN
# bonk0076                                            NaN          NaN
# canadianbarman                                      NaN          NaN
# cassanoj                                            NaN          NaN
# cswhitehorse                                        NaN     0.240000
# dedrinker                                           NaN          NaN
# diablo14                                            NaN          NaN
# dwvarner77                                          NaN     0.154792
# fainster                                            NaN          NaN
# foofightingfrog                                     NaN          NaN
# geckointhebox                                       NaN          NaN
# hixsonj                                             NaN          NaN
# hopdog                                              NaN    -0.031667
# inebrius                                            NaN     0.375000
# jeffress                                            NaN          NaN
# jjohnson                                            NaN          NaN
# juhl31                                              NaN     0.209524
# jwhite1979                                          NaN          NaN
# keethrax                                            NaN          NaN
# leedorham                                           NaN          NaN
# mickcov1                                            NaN          NaN
# mjsheehan08                                         NaN     0.113368
# ndolover                                            NaN          NaN
# pbrian                                              NaN          NaN
# rlambert                                            NaN          NaN
# rodenbach99                                         NaN    -0.092138
# sohio                                               NaN          NaN
# stephendr                                           NaN          NaN
# stingrayvr6                                         NaN          NaN
#
# beer_style            Tripel  Vienna Lager  Weizenbock  Wheatwine  \
# review_profileName
# AlexF               0.000000           NaN         NaN        NaN
# Bajasith                 NaN           NaN    0.190278        NaN
# BaronBeerGoggles         NaN           NaN         NaN        NaN
# Beer4Baltimore      0.151902           NaN         NaN        NaN
# BenH1068                 NaN           NaN         NaN        NaN
# BigJTrucker         0.224862           NaN         NaN        NaN
# BoozySmurf               NaN           NaN         NaN        NaN
# Cavalier92          0.315580           NaN         NaN        NaN
# DaleMcMutt               NaN           NaN         NaN        NaN
# Dhren1979                NaN           NaN         NaN        NaN
# Docer               0.183917           NaN    0.142816        NaN
# Dodt                     NaN      0.300000    0.000000        NaN
# HighGravityBrews         NaN           NaN         NaN        NaN
# Imbiber                  NaN           NaN    0.150000        NaN
# JudgeRoughneck      0.234860      0.081565         NaN        NaN
# RoryDoherty              NaN           NaN         NaN        NaN
# RustyDiamond        0.202793           NaN    0.153030        NaN
# Shadow1100               NaN           NaN         NaN        NaN
# TaddyPorter         0.052707           NaN         NaN        NaN
# TheDeuce            0.229960      0.202035         NaN        NaN
# TinPigeon           0.379386           NaN         NaN        NaN
# Tundruth                 NaN      0.338079         NaN        NaN
# VonSands                 NaN           NaN         NaN        NaN
# Vvall               0.440000           NaN         NaN        NaN
# alcurtsinger             NaN      0.126515         NaN        NaN
# bierguru            0.036667      0.277509         NaN        NaN
# boatyard                 NaN      0.347199         NaN        NaN
# bonk0076            0.000000           NaN         NaN        NaN
# canadianbarman      0.000000           NaN         NaN        NaN
# cassanoj                 NaN           NaN         NaN        NaN
# cswhitehorse        0.139388      0.299167         NaN        NaN
# dedrinker           0.079043           NaN         NaN   0.122386
# diablo14                 NaN      0.219502         NaN        NaN
# dwvarner77               NaN           NaN         NaN        NaN
# fainster            0.310333           NaN         NaN        NaN
# foofightingfrog     0.237143      0.045000         NaN        NaN
# geckointhebox            NaN           NaN         NaN        NaN
# hixsonj                  NaN           NaN         NaN        NaN
# hopdog              0.091202     -0.133333    0.014062   0.166667
# inebrius            0.105620      0.092551    0.106875        NaN
# jeffress                 NaN           NaN         NaN        NaN
# jjohnson                 NaN           NaN         NaN        NaN
# juhl31                   NaN           NaN    0.000000        NaN
# jwhite1979               NaN           NaN         NaN        NaN
# keethrax                 NaN           NaN         NaN        NaN
# leedorham                NaN           NaN         NaN        NaN
# mickcov1                 NaN           NaN         NaN        NaN
# mjsheehan08              NaN           NaN         NaN        NaN
# ndolover                 NaN           NaN         NaN   0.132079
# pbrian              0.174692      0.325758    0.079630        NaN
# rlambert                 NaN           NaN         NaN        NaN
# rodenbach99        -0.024621           NaN         NaN        NaN
# sohio                    NaN           NaN         NaN        NaN
# stephendr          -0.003836           NaN         NaN        NaN
# stingrayvr6         0.214792      0.334048         NaN        NaN
#
# beer_style          Winter Warmer   Witbier
# review_profileName
# AlexF                         NaN -0.150000
# Bajasith                      NaN  0.032414
# BaronBeerGoggles              NaN       NaN
# Beer4Baltimore           0.268452  0.044048
# BenH1068                      NaN       NaN
# BigJTrucker              0.139568  0.174211
# BoozySmurf                    NaN       NaN
# Cavalier92                    NaN       NaN
# DaleMcMutt                    NaN       NaN
# Dhren1979                     NaN       NaN
# Docer                    0.226184  0.190035
# Dodt                     1.000000  0.117229
# HighGravityBrews              NaN       NaN
# Imbiber                  0.135818       NaN
# JudgeRoughneck           0.244033  0.187589
# RoryDoherty                   NaN       NaN
# RustyDiamond                  NaN  0.266923
# Shadow1100                    NaN       NaN
# TaddyPorter                   NaN       NaN
# TheDeuce                 0.115813  0.216845
# TinPigeon                     NaN       NaN
# Tundruth                 0.257251  0.000000
# VonSands                      NaN       NaN
# Vvall                         NaN       NaN
# alcurtsinger                  NaN       NaN
# bierguru                      NaN  0.251567
# boatyard                      NaN       NaN
# bonk0076                      NaN       NaN
# canadianbarman                NaN  0.193878
# cassanoj                      NaN       NaN
# cswhitehorse             0.110546  0.193815
# dedrinker                0.131088  0.147827
# diablo14                      NaN       NaN
# dwvarner77                    NaN  0.068414
# fainster                 0.277424  0.088659
# foofightingfrog               NaN       NaN
# geckointhebox                 NaN       NaN
# hixsonj                       NaN       NaN
# hopdog                   0.007523  0.093289
# inebrius                 0.202344  0.122615
# jeffress                      NaN       NaN
# jjohnson                      NaN       NaN
# juhl31                        NaN       NaN
# jwhite1979                    NaN       NaN
# keethrax                      NaN  0.095327
# leedorham                     NaN  0.090816
# mickcov1                      NaN       NaN
# mjsheehan08                   NaN       NaN
# ndolover                      NaN       NaN
# pbrian                   0.016667  0.187901
# rlambert                      NaN       NaN
# rodenbach99              0.466667  0.320833
# sohio                         NaN       NaN
# stephendr                0.072917  0.128368
# stingrayvr6              0.313889  0.323264
#
# [55 rows x 104 columns]

# %%
# Replace NaN with 0 first, then convert it to sparse.csr_matrix, where 0 values are ignored
senti_matrix=senti_matrix.fillna(0)
sparsem = csr_matrix(senti_matrix)
print("Sparse matrix: \n",sparsem )
# Out:
# Sparse matrix:
#    (0, 2)	0.14752711640211638
#   (0, 4)	0.1696338383838384
#   (0, 9)	0.0914400806308701
#   (0, 10)	0.23076923076923073
#   (0, 11)	0.164152862933589
#   (0, 12)	0.20608971870520787
#   (0, 17)	0.1388888888888889
#   (0, 19)	0.11198509711794738
#   (0, 20)	0.0946049532478104
#   (0, 22)	0.16350000000000003
#   (0, 25)	0.11176948051948052
#   (0, 29)	0.3755
#   (0, 58)	0.1612561728395062
#   (0, 60)	0.23551607123035695
#   (0, 74)	0.2002450980392157
#   (0, 84)	0.1090807194754563
#   (0, 89)	0.2285757575757576
#   (0, 92)	0.22111685463659148
#   (0, 98)	0.16207070707070703
#   (0, 103)	0.2640740740740741
#   (1, 49)	0.19819548872180454
#   (1, 76)	0.11016666666666666
#   (1, 93)	0.2394871794871795
#   (2, 14)	0.2549444444444444
#   (3, 2)	0.19640151515151513
#   :	:
#   (22785, 15)	0.0878720238095238
#   (22785, 16)	0.08660841473341471
#   (22785, 17)	0.21827976190476195
#   (22785, 39)	0.1919871794871795
#   (22785, 49)	0.20946969696969697
#   (22785, 58)	0.2204545454545455
#   (22785, 60)	0.09073809523809526
#   (22785, 61)	0.2768671679197995
#   (22785, 79)	0.33039583333333333
#   (22785, 85)	0.18571428571428575
#   (22785, 87)	0.29027777777777775
#   (22785, 93)	0.26964154411764707
#   (22785, 99)	0.19955952380952377
#   (22785, 102)	0.18047619047619046
#   (22785, 103)	0.23888888888888887
#   (22786, 12)	0.5472222222222223
#   (22787, 39)	0.07976866883116884
#   (22787, 44)	0.2455128205128205
#   (22787, 49)	0.20937499999999998
#   (22787, 53)	0.29642857142857143
#   (22787, 55)	0.24358974358974358
#   (22787, 60)	0.12435897435897435
#   (22787, 70)	-0.13112244897959177
#   (22788, 0)	0.2664285714285714
#   (22788, 44)	0.21456481481481482

# %%
# SpectralClustering is chosen over K-Means and DBScan since overall it handles high dimensional data and sparse data better
# I used n_clusters=15, didn't find an easy way to do elbow anaylysis using inertia like one in K-Means. 
# My understanding of the reason is that both SpectralClustering and DBScan are not centriod based
# Not sure how to choose best n_clusters?
clustering = SpectralClustering(n_clusters=15,assign_labels="discretize", random_state=0).fit(sparsem)
clustering.labels_
# Not sure if this is correct - index order is preserved?
senti_matrix['cluster']=clustering.labels_

# %%
# Not sure if PCA is correctly used here since it doesn't take the sparse matrix sparsem, has to use senti_matrix, where null are filled with 0
# if PCA can't be used, not sure what other plotting options to present the clustering visually?
# last choice could be to display the user list for each cluster in a table

fig = plt.figure(1, figsize=(10, 10))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()

pca = PCA(n_components=3)
pca.fit(senti_matrix)
X = pca.transform(senti_matrix)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=clustering.labels_, cmap=plt.cm.nipy_spectral,alpha=0.8)

# label beer drinkers to see if they are similar
ax.text(X[701, 0], X[701, 1], X[701, 2], senti_matrix.index[701], size=20, zorder=1,   color='k') 
ax.text(X[1141, 0], X[1141, 1], X[1141, 2], senti_matrix.index[1141], size=20, zorder=1,   color='k') 
ax.text(X[911, 0], X[911, 1], X[91, 2], senti_matrix.index[911], size=20, zorder=1,   color='k') 
ax.text(X[0, 0], X[0, 1], X[0, 2], senti_matrix.index[0], size=20, zorder=1,   color='k') 

plt.show()

# %%
# Not sure if PCA is correctly used here since it doesn't take the sparse matrix sparsem, has to use senti_matrix, where null are filled with 0
# if PCA can't be used, not sure what other plotting options to present the clustering visually?
# last choice could be to display the user list for each cluster in a table

fig = plt.figure(1, figsize=(10, 10))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()

pca = PCA(n_components=3)
pca.fit(senti_matrix)
X = pca.transform(senti_matrix)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=clustering.labels_, cmap=plt.cm.nipy_spectral,alpha=0.8)

# label beer drinkers to see if they are similar
ax.text(X[701, 0], X[701, 1], X[701, 2], senti_matrix.index[701], size=20, zorder=1,   color='k') 
ax.text(X[1141, 0], X[1141, 1], X[1141, 2], senti_matrix.index[1141], size=20, zorder=1,   color='k') 
ax.text(X[911, 0], X[911, 1], X[91, 2], senti_matrix.index[911], size=20, zorder=1,   color='k') 
ax.text(X[0, 0], X[0, 1], X[0, 2], senti_matrix.index[0], size=20, zorder=1,   color='k') 

plt.show()

# %%
# Similar beer drinkers can be reviewed by providing a cluster id
senti_matrix_list[senti_matrix['cluster']==3]['review_profileName']
# Out:
# 2061         ChugginOil
# 2787      Dreadnaught33
# 3711             Gtreid
# 5031               Klym
# 7569       ShadesOfGray
# 8843         Urbancaver
# 9180                Xul
# 9208     YonderWanderer
# 9341         abuliarose
# 10761          blitz134
# 11251           bultrey
# 15613          jminsc76
# 16541          kzoobrew
# 16695          levifunk
# 17150         match1112
# 18161          nataku00
# 19074       pmlondrigan
# 19578             ricke
# 20433         sisuspeed
# Name: review_profileName, dtype: object
